# %% [markdown]
# # 🧹 Machine Learning Notebook 📚
#
# Welcome to this Jupyter Notebook! 🎉
#
# In this notebook, we will be going through the process of cleaning up a database, then preparing it for machine learning (ML), and finally running multiple algorithms to test which is more precise. This involves identifying and correcting errors in the dataset, dealing with missing values, normalizing and splitting test and training dataframes. 📊
#
# We will be using powerful Python libraries such as `pandas` for data manipulation, `numpy` for numerical operations, `tabulate` for printing tables and `sklearn`'s `SimpleImputer` and `StandardScaler` for handling missing values and standardizing data respectively. 🧮
#
# For machine learning specifically, we will be using `mean_squared_error` for calculating the precision of our models, and `train_test_split` to create our testing/training set pairs. 🎯
#
# Our 3 regressors to use are `DecisionTreeRegressor` `RandomForestRegressor` and `LinearRegressor`. These are powerful tools that will help us predict outcomes based on our data. 🤖
#
# So, let's dive in and start cleaning! 🏊‍♀️

# %%
# Import necessary libraries for data science and data cleanup
import pandas as pd
import numpy as np
import tabulate

from sklearn.model_selection import train_test_split # for splitting data into training and testing sets
from scipy.stats import zscore # for outlier detection
from sklearn.preprocessing import StandardScaler # for scaling data
from sklearn.metrics import mean_squared_error # for calculating error

# %%
df = pd.read_csv('breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.describe().transpose()
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01

# %% [markdown]
# In this case, we can tell that our `diagnosis` column will be our label for ML 🎯, while every other column (apart from `id`) corresponds to either the worst observation 👎, the mean observation 📊, or the standard error $ (\frac{\sigma}{\sqrt{n}}) $
#
# As such, let's numerize `['diagnosis']` with M = 1 (malignant) 😷, and B = 0 (benign) 😊

# %%
df['diagnosis'] = pd.to_numeric(df['diagnosis'].replace({'M': 1, 'B': 0}))
df['diagnosis'].describe()
# Out:
# C:\Users\nuxap\AppData\Local\Temp\ipykernel_4624\57912900.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['diagnosis'] = pd.to_numeric(df['diagnosis'].replace({'M': 1, 'B': 0}))
# count    569.000000
# mean       0.372583
# std        0.483918
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: diagnosis, dtype: float64

# %% [markdown]
# 🔍 Let's also check for duplicates 🔎

# %%
df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Then let's tabulate all dtypes, null values and outliers 📊🔍📈

# %%
# Get amount of null values for each column
null_values = df.isnull().sum()
# Get the data types of each column
data_types = df.dtypes

# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])
# Define a function to detect outliers using the IQR method
def detect_outliers(series):
    z_scores = zscore(series)
    outliers = np.abs(z_scores) > 3
    return outliers.sum()
# Apply the function to detect outliers only on numeric columns
outliers = numeric_df.apply(detect_outliers)

# Tabulate the results
summary_table = pd.DataFrame({'Data Types': data_types, 'Null Values': null_values, 'Outliers': outliers})
print(tabulate.tabulate(summary_table, headers='keys', tablefmt='pretty'))
# Out:
# +-------------------------+------------+-------------+----------+
# |                         | Data Types | Null Values | Outliers |
# +-------------------------+------------+-------------+----------+
# |           id            |   int64    |      0      |    11    |
# |        diagnosis        |   int64    |      0      |    0     |
# |       radius_mean       |  float64   |      0      |    5     |
# |      texture_mean       |  float64   |      0      |    4     |
# |     perimeter_mean      |  float64   |      0      |    7     |
# |        area_mean        |  float64   |      0      |    8     |
# |     smoothness_mean     |  float64   |      0      |    5     |
# |    compactness_mean     |  float64   |      0      |    9     |
# |     concavity_mean      |  float64   |      0      |    9     |
# |   concave points_mean   |  float64   |      0      |    6     |
# |      symmetry_mean      |  float64   |      0      |    5     |
# | fractal_dimension_mean  |  float64   |      0      |    7     |
# |        radius_se        |  float64   |      0      |    7     |
# |       texture_se        |  float64   |      0      |    9     |
# |      perimeter_se       |  float64   |      0      |    8     |
# |         area_se         |  float64   |      0      |    6     |
# |      smoothness_se      |  float64   |      0      |    7     |
# |     compactness_se      |  float64   |      0      |    12    |
# |      concavity_se       |  float64   |      0      |    6     |
# |    concave points_se    |  float64   |      0      |    6     |
# |       symmetry_se       |  float64   |      0      |    11    |
# |  fractal_dimension_se   |  float64   |      0      |    10    |
# |      radius_worst       |  float64   |      0      |    6     |
# |      texture_worst      |  float64   |      0      |    4     |
# |     perimeter_worst     |  float64   |      0      |    6     |
# |       area_worst        |  float64   |      0      |    10    |
# |    smoothness_worst     |  float64   |      0      |    3     |
# |    compactness_worst    |  float64   |      0      |    10    |
# |     concavity_worst     |  float64   |      0      |    7     |
# |  concave points_worst   |  float64   |      0      |    0     |
# |     symmetry_worst      |  float64   |      0      |    9     |
# | fractal_dimension_worst |  float64   |      0      |    9     |
# +-------------------------+------------+-------------+----------+

# %% [markdown]
# Our database has:
# * only floats (except of course, our `id` and `label` columns) 🧮
# * no null values 🚫
# * a very varied amount of *outliers* 📊
#
# as such I'd rather run it as-is. 🏃‍♀️
#
# ______________________
#
# # ML preparation 🤖

# %% [markdown]
# We drop our `id` column, as it's not useful for our ML purposes. 🗑️ As well as separating our `label` column. 🏷️

# %%
# Drop the 'id' column
df = df.drop(['id'], axis=1)

# Separate the 'diagnosis' column as our label
labels = df['diagnosis']
df = df.drop(['diagnosis'], axis=1)

# %% [markdown]
# In this step, we create different, normalized dataframes, for testing and experimenting with our regression results. This is an important step in our data analysis process 📊🧪🔬.
#
# Additionally, we'll do the same thing for subsets of our dataframe. We'll create one for `_means` only, another for `_worsts` only, and another for standard errors (`_se`) only. This will allow us to test which is more precise at predicting malevolent vs benevolent tumors 📈🔎📚.

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
df_normalized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df_means = df.filter(regex='_mean$')
df_se = df.filter(regex='_se$')
df_worst = df.filter(regex='_worst$')

# fit and transform the data
df_means = scaler.fit_transform(df_means)
df_se = scaler.fit_transform(df_se)
df_worst = scaler.fit_transform(df_worst)

# convert the numpy arrays back to dataframes
df_means = pd.DataFrame(df_means)
df_se = pd.DataFrame(df_se)
df_worst = pd.DataFrame(df_worst)

# %% [markdown]
# Here are the dataframes that will be used for ML regression: 📊
#
# 1. `df`: This is the **original dataframe** that contains all the data. It includes various descriptive statistics such as 'radius_mean', 'radius_se', 'radius_worst', etc. 📝
#
# 2. `df_normalized`: This dataframe is a **normalized** version of the original dataframe `df`. All the values in this dataframe are scaled using `StandardScaler()` from `sklearn`. 🔄
#
# 3. `df_means`: This dataframe is a **subset** of the original dataframe `df`. It only contains the **mean** values of the features. 🎯
#
# 4. `df_means_normalized`: This dataframe is a **normalized** version of `df_means`. 🔄
#
# and so on with each metric in `df`. 🔍

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# We set up the 🎯 **target variable**, define ⚙️ **hyperparameters**, create a 📝 **list of all our dataframes** (each representing a different version of the data), specifying the 🤖 machine learning models to use, and naming each dataframe for easy reference. 📚

# %%
# Define the target variable
y = labels

# Define the hyperparameters
hyperparameters = [2, 3, 4, 5, 6]

# Create a list of all dataframes
dfs = [df, df_normalized, df_means, df_means_normalized, df_se, df_se_normalized, df_worst, df_worst_normalized]

# Create a list of all regressors
regressors = [DecisionTreeRegressor, LinearRegression, RandomForestRegressor]

# Create a list of dataframe names
df_names = ['df', 'df_normalized', 'df_means', 'df_means_normalized', 'df_se', 'df_se_normalized', 'df_worst', 'df_worst_normalized']

# %% [markdown]
# We split 🍴, train 🚂 and test 🧪 each dataframe with each regressor, under each set of hyperparameters previously defined. 🎯

# %%
# Initialize the results list for tabulating later
results = []

# Loop over all dataframes
for df, df_name in zip(dfs, df_names):
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=42)

    # Loop over all regressors
    for regressor in regressors:
        # Check if the regressor is LinearRegression
        if regressor == LinearRegression:
            # LinearRegression does not have hyperparameters so we can initialize it directly
            model = regressor()
            
            # Fit the model
            model.fit(X_train, y_train)

            # Make predictions
            y_pred = model.predict(X_test)

            # Calculate the mean squared error
            mse = mean_squared_error(y_test, y_pred)

            # Append the results to the results list
            results.append([df_name, regressor.__name__, None, mse]) # None is used as a placeholder for hyperparameters since LinearRegression does not have hyperparameters
            print(f"Finished {df_name} with {regressor.__name__}")
            
        else:
            # Loop over all hyperparameters for the other 2 regressors
            for hyperparameter in hyperparameters:
                # Initialize the regressor
                if regressor == DecisionTreeRegressor:
                    model = regressor(max_depth=hyperparameter, random_state=42)
                elif regressor == RandomForestRegressor:
                    model = regressor(n_estimators=int(hyperparameter), random_state=41)

                # Fit the model
                model.fit(X_train, y_train)

                # Make predictions
                y_pred = model.predict(X_test)

                # Calculate the mean squared error
                mse = mean_squared_error(y_test, y_pred)

                # Append the results to the results list
                results.append([df_name, regressor.__name__, hyperparameter, mse])
                print(f"Finished {df_name} with {regressor.__name__} and hyperparameter {hyperparameter}")
# Out:
# Finished df with DecisionTreeRegressor and hyperparameter 2
# Finished df with DecisionTreeRegressor and hyperparameter 3
# Finished df with DecisionTreeRegressor and hyperparameter 4
# Finished df with DecisionTreeRegressor and hyperparameter 5
# Finished df with DecisionTreeRegressor and hyperparameter 6
# Finished df with LinearRegression
# Finished df with RandomForestRegressor and hyperparameter 2
# Finished df with RandomForestRegressor and hyperparameter 3
# Finished df with RandomForestRegressor and hyperparameter 4
# Finished df with RandomForestRegressor and hyperparameter 5
# Finished df with RandomForestRegressor and hyperparameter 6
# Finished df_normalized with DecisionTreeRegressor and hyperparameter 2
# Finished df_normalized with DecisionTreeRegressor and hyperparameter 3
# Finished df_normalized with DecisionTreeRegressor and hyperparameter 4
# Finished df_normalized with DecisionTreeRegressor and hyperparameter 5
# Finished df_normalized with DecisionTreeRegressor and hyperparameter 6
# Finished df_normalized with LinearRegression
# Finished df_normalized with RandomForestRegressor and hyperparameter 2
# Finished df_normalized with RandomForestRegressor and hyperparameter 3
# Finished df_normalized with RandomForestRegressor and hyperparameter 4
# Finished df_normalized with RandomForestRegressor and hyperparameter 5
# Finished df_normalized with RandomForestRegressor and hyperparameter 6
# Finished df_means with DecisionTreeRegressor and hyperparameter 2
# Finished df_means with DecisionTreeRegressor and hyperparameter 3
# Finished df_means with DecisionTreeRegressor and hyperparameter 4
# Finished df_means with DecisionTreeRegressor and hyperparameter 5
# Finished df_means with DecisionTreeRegressor and hyperparameter 6
# Finished df_means with LinearRegression
# Finished df_means with RandomForestRegressor and hyperparameter 2
# Finished df_means with RandomForestRegressor and hyperparameter 3
# Finished df_means with RandomForestRegressor and hyperparameter 4
# Finished df_means with RandomForestRegressor and hyperparameter 5
# Finished df_means with RandomForestRegressor and hyperparameter 6
# Finished df_means_normalized with DecisionTreeRegressor and hyperparameter 2
# Finished df_means_normalized with DecisionTreeRegressor and hyperparameter 3
# Finished df_means_normalized with DecisionTreeRegressor and hyperparameter 4
# Finished df_means_normalized with DecisionTreeRegressor and hyperparameter 5
# Finished df_means_normalized with DecisionTreeRegressor and hyperparameter 6
# Finished df_means_normalized with LinearRegression
# Finished df_means_normalized with RandomForestRegressor and hyperparameter 2
# Finished df_means_normalized with RandomForestRegressor and hyperparameter 3
# Finished df_means_normalized with RandomForestRegressor and hyperparameter 4
# Finished df_means_normalized with RandomForestRegressor and hyperparameter 5
# Finished df_means_normalized with RandomForestRegressor and hyperparameter 6
# Finished df_se with DecisionTreeRegressor and hyperparameter 2
# Finished df_se with DecisionTreeRegressor and hyperparameter 3
# Finished df_se with DecisionTreeRegressor and hyperparameter 4
# Finished df_se with DecisionTreeRegressor and hyperparameter 5
# Finished df_se with DecisionTreeRegressor and hyperparameter 6
# Finished df_se with LinearRegression
# Finished df_se with RandomForestRegressor and hyperparameter 2
# Finished df_se with RandomForestRegressor and hyperparameter 3
# Finished df_se with RandomForestRegressor and hyperparameter 4
# Finished df_se with RandomForestRegressor and hyperparameter 5
# Finished df_se with RandomForestRegressor and hyperparameter 6
# Finished df_se_normalized with DecisionTreeRegressor and hyperparameter 2
# Finished df_se_normalized with DecisionTreeRegressor and hyperparameter 3
# Finished df_se_normalized with DecisionTreeRegressor and hyperparameter 4
# Finished df_se_normalized with DecisionTreeRegressor and hyperparameter 5
# Finished df_se_normalized with DecisionTreeRegressor and hyperparameter 6
# Finished df_se_normalized with LinearRegression
# Finished df_se_normalized with RandomForestRegressor and hyperparameter 2
# Finished df_se_normalized with RandomForestRegressor and hyperparameter 3
# Finished df_se_normalized with RandomForestRegressor and hyperparameter 4
# Finished df_se_normalized with RandomForestRegressor and hyperparameter 5
# Finished df_se_normalized with RandomForestRegressor and hyperparameter 6
# Finished df_worst with DecisionTreeRegressor and hyperparameter 2
# Finished df_worst with DecisionTreeRegressor and hyperparameter 3
# Finished df_worst with DecisionTreeRegressor and hyperparameter 4
# Finished df_worst with DecisionTreeRegressor and hyperparameter 5
# Finished df_worst with DecisionTreeRegressor and hyperparameter 6
# Finished df_worst with LinearRegression
# Finished df_worst with RandomForestRegressor and hyperparameter 2
# Finished df_worst with RandomForestRegressor and hyperparameter 3
# Finished df_worst with RandomForestRegressor and hyperparameter 4
# Finished df_worst with RandomForestRegressor and hyperparameter 5
# Finished df_worst with RandomForestRegressor and hyperparameter 6
# Finished df_worst_normalized with DecisionTreeRegressor and hyperparameter 2
# Finished df_worst_normalized with DecisionTreeRegressor and hyperparameter 3
# Finished df_worst_normalized with DecisionTreeRegressor and hyperparameter 4
# Finished df_worst_normalized with DecisionTreeRegressor and hyperparameter 5
# Finished df_worst_normalized with DecisionTreeRegressor and hyperparameter 6
# Finished df_worst_normalized with LinearRegression
# Finished df_worst_normalized with RandomForestRegressor and hyperparameter 2
# Finished df_worst_normalized with RandomForestRegressor and hyperparameter 3
# Finished df_worst_normalized with RandomForestRegressor and hyperparameter 4
# Finished df_worst_normalized with RandomForestRegressor and hyperparameter 5
# Finished df_worst_normalized with RandomForestRegressor and hyperparameter 6

# %% [markdown]
# 📊 We tabulate the results, ordered from least error to most error 📈

# %%
# Convert the 'results' list to a pandas DataFrame
results_df = pd.DataFrame(results, columns=["DataFrame", "Regressor", "Hyperparameter", "MSE"])

# Sort the results by ascending MSE
results_df = results_df.sort_values("MSE")

# Print the tabulated results
print(tabulate.tabulate(results_df, headers=["DataFrame", "Regressor", "Hyperparameter", "MSE"], tablefmt='pretty'))
# Out:
# +----+---------------------+-----------------------+----------------+----------------------+
# |    |      DataFrame      |       Regressor       | Hyperparameter |         MSE          |
# +----+---------------------+-----------------------+----------------+----------------------+
# | 30 |      df_means       | RandomForestRegressor |      4.0       | 0.03399122807017544  |
# | 41 | df_means_normalized | RandomForestRegressor |      4.0       | 0.03399122807017544  |
# | 31 |      df_means       | RandomForestRegressor |      5.0       | 0.03438596491228071  |
# | 42 | df_means_normalized | RandomForestRegressor |      5.0       | 0.03438596491228071  |
# | 29 |      df_means       | RandomForestRegressor |      3.0       | 0.03508771929824561  |
# | 40 | df_means_normalized | RandomForestRegressor |      3.0       | 0.03508771929824561  |
# | 43 | df_means_normalized | RandomForestRegressor |      6.0       | 0.03533138401559454  |
# | 32 |      df_means       | RandomForestRegressor |      6.0       | 0.03533138401559454  |
# | 28 |      df_means       | RandomForestRegressor |      2.0       | 0.03728070175438596  |
# | 39 | df_means_normalized | RandomForestRegressor |      2.0       | 0.03728070175438596  |
# | 34 | df_means_normalized | DecisionTreeRegressor |      3.0       | 0.04170374333681208  |
# | 23 |      df_means       | DecisionTreeRegressor |      3.0       | 0.04170374333681208  |
# | 10 |         df          | RandomForestRegressor |      6.0       | 0.046052631578947366 |
# | 21 |    df_normalized    | RandomForestRegressor |      6.0       | 0.046052631578947366 |
# | 9  |         df          | RandomForestRegressor |      5.0       | 0.04631578947368421  |
# | 20 |    df_normalized    | RandomForestRegressor |      5.0       | 0.04631578947368421  |
# | 17 |    df_normalized    | RandomForestRegressor |      2.0       | 0.04824561403508772  |
# | 6  |         df          | RandomForestRegressor |      2.0       | 0.04824561403508772  |
# | 12 |    df_normalized    | DecisionTreeRegressor |      3.0       | 0.04865813474343103  |
# | 1  |         df          | DecisionTreeRegressor |      3.0       | 0.04865813474343103  |
# | 7  |         df          | RandomForestRegressor |      3.0       | 0.04873294346978557  |
# | 18 |    df_normalized    | RandomForestRegressor |      3.0       | 0.04873294346978557  |
# | 74 |      df_worst       | RandomForestRegressor |      4.0       | 0.048793859649122806 |
# | 85 | df_worst_normalized | RandomForestRegressor |      4.0       | 0.048793859649122806 |
# | 19 |    df_normalized    | RandomForestRegressor |      4.0       | 0.05043859649122807  |
# | 8  |         df          | RandomForestRegressor |      4.0       | 0.05043859649122807  |
# | 35 | df_means_normalized | DecisionTreeRegressor |      4.0       | 0.050488732057553706 |
# | 24 |      df_means       | DecisionTreeRegressor |      4.0       | 0.050488732057553706 |
# | 84 | df_worst_normalized | RandomForestRegressor |      3.0       | 0.050682261208576995 |
# | 73 |      df_worst       | RandomForestRegressor |      3.0       | 0.050682261208576995 |
# | 76 |      df_worst       | RandomForestRegressor |      6.0       |  0.050682261208577   |
# | 87 | df_worst_normalized | RandomForestRegressor |      6.0       |  0.050682261208577   |
# | 77 | df_worst_normalized | DecisionTreeRegressor |      2.0       | 0.05094560543490428  |
# | 66 |      df_worst       | DecisionTreeRegressor |      2.0       | 0.05094560543490428  |
# | 2  |         df          | DecisionTreeRegressor |      4.0       | 0.052394107464215155 |
# | 13 |    df_normalized    | DecisionTreeRegressor |      4.0       | 0.052394107464215155 |
# | 75 |      df_worst       | RandomForestRegressor |      5.0       | 0.05263157894736842  |
# | 86 | df_worst_normalized | RandomForestRegressor |      5.0       | 0.05263157894736842  |
# | 3  |         df          | DecisionTreeRegressor |      5.0       | 0.05268006325337152  |
# | 14 |    df_normalized    | DecisionTreeRegressor |      5.0       | 0.05268006325337152  |
# | 33 | df_means_normalized | DecisionTreeRegressor |      2.0       | 0.05300190501543448  |
# | 22 |      df_means       | DecisionTreeRegressor |      2.0       | 0.05300190501543448  |
# | 69 |      df_worst       | DecisionTreeRegressor |      5.0       | 0.053686234036773126 |
# | 80 | df_worst_normalized | DecisionTreeRegressor |      5.0       | 0.053686234036773126 |
# | 78 | df_worst_normalized | DecisionTreeRegressor |      3.0       | 0.05552471461748264  |
# | 67 |      df_worst       | DecisionTreeRegressor |      3.0       | 0.05552471461748264  |
# | 64 |  df_se_normalized   | RandomForestRegressor |      5.0       | 0.05684210526315791  |
# | 53 |        df_se        | RandomForestRegressor |      5.0       | 0.05684210526315791  |
# | 82 | df_worst_normalized |   LinearRegression    |      nan       | 0.05742353181209769  |
# | 71 |      df_worst       |   LinearRegression    |      nan       | 0.05742353181209769  |
# | 65 |  df_se_normalized   | RandomForestRegressor |      6.0       | 0.05823586744639376  |
# | 54 |        df_se        | RandomForestRegressor |      6.0       | 0.05823586744639376  |
# | 63 |  df_se_normalized   | RandomForestRegressor |      4.0       | 0.05866228070175439  |
# | 52 |        df_se        | RandomForestRegressor |      4.0       | 0.05866228070175439  |
# | 11 |    df_normalized    | DecisionTreeRegressor |      2.0       |  0.0589937547627024  |
# | 0  |         df          | DecisionTreeRegressor |      2.0       |  0.0589937547627024  |
# | 62 |  df_se_normalized   | RandomForestRegressor |      3.0       | 0.059454191033138405 |
# | 51 |        df_se        | RandomForestRegressor |      3.0       | 0.059454191033138405 |
# | 68 |      df_worst       | DecisionTreeRegressor |      4.0       | 0.05970398277727081  |
# | 79 | df_worst_normalized | DecisionTreeRegressor |      4.0       | 0.05970398277727081  |
# | 72 |      df_worst       | RandomForestRegressor |      2.0       | 0.06140350877192982  |
# | 83 | df_worst_normalized | RandomForestRegressor |      2.0       | 0.06140350877192982  |
# | 4  |         df          | DecisionTreeRegressor |      6.0       | 0.06159844054580896  |
# | 15 |    df_normalized    | DecisionTreeRegressor |      6.0       | 0.06159844054580896  |
# | 81 | df_worst_normalized | DecisionTreeRegressor |      6.0       | 0.06167047950988082  |
# | 70 |      df_worst       | DecisionTreeRegressor |      6.0       | 0.06167047950988082  |
# | 36 | df_means_normalized | DecisionTreeRegressor |      5.0       | 0.06215257716124379  |
# | 25 |      df_means       | DecisionTreeRegressor |      5.0       | 0.06215257716124379  |
# | 26 |      df_means       | DecisionTreeRegressor |      6.0       | 0.06249957843474506  |
# | 37 | df_means_normalized | DecisionTreeRegressor |      6.0       | 0.06249957843474506  |
# | 55 |  df_se_normalized   | DecisionTreeRegressor |      2.0       | 0.06379707192410501  |
# | 44 |        df_se        | DecisionTreeRegressor |      2.0       | 0.06379707192410501  |
# | 5  |         df          |   LinearRegression    |      nan       | 0.06410886247029421  |
# | 16 |    df_normalized    |   LinearRegression    |      nan       | 0.06410886247029461  |
# | 50 |        df_se        | RandomForestRegressor |      2.0       | 0.06798245614035088  |
# | 61 |  df_se_normalized   | RandomForestRegressor |      2.0       | 0.06798245614035088  |
# | 27 |      df_means       |   LinearRegression    |      nan       | 0.07911450027043931  |
# | 38 | df_means_normalized |   LinearRegression    |      nan       | 0.07911450027043931  |
# | 56 |  df_se_normalized   | DecisionTreeRegressor |      3.0       | 0.08497326202476535  |
# | 45 |        df_se        | DecisionTreeRegressor |      3.0       | 0.08497326202476535  |
# | 57 |  df_se_normalized   | DecisionTreeRegressor |      4.0       | 0.08703982610506383  |
# | 46 |        df_se        | DecisionTreeRegressor |      4.0       | 0.08703982610506383  |
# | 60 |  df_se_normalized   |   LinearRegression    |      nan       | 0.11401716077910122  |
# | 49 |        df_se        |   LinearRegression    |      nan       | 0.11401716077910122  |
# | 58 |  df_se_normalized   | DecisionTreeRegressor |      5.0       | 0.11718244463865521  |
# | 47 |        df_se        | DecisionTreeRegressor |      5.0       | 0.11718244463865521  |
# | 48 |        df_se        | DecisionTreeRegressor |      6.0       | 0.11945654427539469  |
# | 59 |  df_se_normalized   | DecisionTreeRegressor |      6.0       | 0.11945654427539469  |
# +----+---------------------+-----------------------+----------------+----------------------+

# %% [markdown]
# As we can see, our best regression algorithm is running a `RandomForestRegressor` on `df_means`, with 4 estimators. 🌲🌲🌲🌲
#
# Now we should scale up our exploratory database analysis and use more data to run our regressions; and ultimately help out predict malign vs benign tumorous breast cancer growths from observation measurements. 🔬📊
#
# Finally, we plot our model breakdown. 📈📉

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

for column in results_df.columns:
    if column != 'MSE':
        plt.figure(figsize=(10, 6))
        plt.scatter(results_df[column], results_df['MSE'])
        plt.xlabel(column)
        plt.xticks(rotation=45)  # This line rotates the xlabels 45 degrees
        plt.ylabel('Mean Standard Error')
        plt.ylim(bottom=0)  # This line makes y always start at 0
        plt.title(f'Mean Standard Error vs {column}')
        plt.gca().invert_yaxis()  # This line inverts the y-axis
        plt.show()

# %%
from sklearn.metrics import mean_squared_error

# Assuming randomtrees_200 is your trained RandomForestRegressor model
# And it has been trained like this:
randomtrees_200 = RandomForestRegressor(n_estimators=200, random_state=42)
randomtrees_200.fit(X_train, y_train)

# Predict on training data
train_preds = randomtrees_200.predict(X_train)

# Predict on testing data
test_preds = randomtrees_200.predict(X_test)

# Calculate the mean squared error on training data
train_mse = mean_squared_error(y_train, train_preds)

# Calculate the mean squared error on testing data
test_mse = mean_squared_error(y_test, test_preds)

# Print the mean squared errors
print(f'Training MSE: {train_mse}')
print(f'Testing MSE: {test_mse}')
# Out:
# Training MSE: 0.004911868131868131
# Testing MSE: 0.03779078947368421

# %% [markdown]
# This shows our model may be overfitted, and we can reduce overhead and improve precision by reducing estimators📊. We do and plot to check the best model for precision vs overfitting📈:

# %%
# List of numbers of estimators
n_estimators = list(range(1, 33))

# Lists to store the mean squared errors
train_errors = []
test_errors = []

# Train a model for each number of estimators
for n in n_estimators:
    model = RandomForestRegressor(n_estimators=n, random_state=45)
    model.fit(X_train, y_train)
    
    # Predict and calculate the mean squared error on training data
    train_preds = model.predict(X_train)
    train_mse = mean_squared_error(y_train, train_preds)
    train_errors.append(train_mse)
    
    # Predict and calculate the mean squared error on testing data
    test_preds = model.predict(X_test)
    test_mse = mean_squared_error(y_test, test_preds)
    test_errors.append(test_mse)

# Plot the training and testing errors
plt.figure(figsize=(10, 5))
plt.plot(n_estimators, train_errors, label='Training error')
plt.plot(n_estimators, test_errors, label='Testing error')
plt.xlabel('Number of estimators')
plt.xticks(range(0, 33, 3))
plt.ylabel('Mean squared error')
plt.legend()
plt.show()

# %% [markdown]
# 🎯 It seems our sweet-spot lies around 9 estimators.
#
# 👩‍💻 As such, we should train our Tumor-Analyzing algorithm as a Random Forest Regressor (to a depth of 9 estimators), using the non-normalized means of the data for each patient, for an algorithm with a ~97% precision. 📈

# %% [markdown]
# #### Thank you for reading this Jupyter Notebook. If you have any questions or need further clarification, feel free to ask. Happy coding!

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = "https://resumendiario.elturf.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 8
#       6 url = "https://resumendiario.elturf.com/"
#       7 response = requests.get(url)
# ----> 8 soup = BeautifulSoup(response.text, 'html.parser')
#
# File c:\Python312\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Python312\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Python312\Lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File c:\Python312\Lib\html\parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File c:\Python312\Lib\html\parser.py:156, in HTMLParser.goahead(self, end)
#     154 match = self.interesting.search(rawdata, i)  # < or &
#     155 if match:
# --> 156     j = match.start()
#     157 else:
#     158     if self.cdata_elem:
#
# KeyboardInterrupt:

# %%
data = soup.find_all('td', class_='ttt_estad_estad_td')

# Extract the data from the HTML
extracted_data = []
for item in data:
    extracted_data.append(item.text)

# Organize the data into a tabular format. You could use pandas for this.
df = pd.DataFrame(extracted_data)

# %%
# Define the column names
column_names = ["nro_carrera", "tipo_carrera", "tipo_carrera_alt", "distancia", "lugar_1", "lugar_2", "lugar_3", "empty"]
# Use the index of '\xa0' to split the extracted_data into two lists
index = extracted_data.index('\xa0')

# The first list is from the start to the index of '\xa0'
extracted_data = extracted_data[:index]

# Break the extracted_data_1 into rows every 8 columns
rows = [extracted_data[i:i+8] for i in range(0, len(extracted_data), 8)]

# Create a new dataframe with the rows and column names
df = pd.DataFrame(rows, columns=column_names)

# Split the data in 'lugar_1', 'lugar_2', and 'lugar_3' columns
# Use regular expression to remove data after ")"
df['lugar_1'] = df['lugar_1'].apply(lambda x: re.sub(r'\).*', ')', x))
df['lugar_2'] = df['lugar_2'].apply(lambda x: re.sub(r'\).*', ')', x))
df = df.drop('empty', axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 4
#       2 column_names = ["nro_carrera", "tipo_carrera", "tipo_carrera_alt", "distancia", "lugar_1", "lugar_2", "lugar_3", "empty"]
#       3 # Use the index of '\xa0' to split the extracted_data into two lists
# ----> 4 index = extracted_data.index('\xa0')
#       6 # The first list is from the start to the index of '\xa0'
#       7 extracted_data = extracted_data[:index]
#
# ValueError: '\xa0' is not in list

# %%
df.head(50)
# Out:
#                   nro_carrera           tipo_carrera  \
# 0                          1ª                    Alw
# 1                          2ª                    Clm
# 2                          3ª                    Clm
# 3                          4ª                    Clm
# 4                          5ª                    Mcl
# 5                          6ª                    Clm
# 6                          7ª                    Clm
# 7                          1ª                     Hd
# 8                          2ª                     Cd
# 9                          3ª                     Hd
# 10                         4ª                     Hd
# 11                         5ª                     Cd
# 12                         6ª                     Hd
# 13                         7ª                     Hd
# 14                         8ª                     Cd
# 15                         9ª                     Cl
# 16                        10ª                     Hd
# 17                        11ª                     Cl
# 18                        12ª                     Hd
# 19                        13ª                     Hd
# 20                        14ª                     Hd
# 21                        15ª                     Hd
# 22                        16ª                     Hd
# 23                        17ª                     Hd
# 24                        18ª                     Hd
# 25                        19ª                     Hd
# 26                         1ª                     Cd
# 27                         2ª                     Cd
# 28                         3ª                     Cd
# 29                         4ª                     Cd
# 30                         5ª                     Cd
# 31                         6ª                     Cd
# 32                         7ª                     Cd
# 33                         8ª                     Cd
# 34                         9ª                    Esp
# 35                        10ª                     Cd
# 36                        11ª                     Cd
# 37                        12ª                     Cd
# 38                         1ª                     Cd
# 39                         2ª                     RE
# 40                         3ª                     Cd
# 41                         4ª                     Cl
# 42                         5ª                     Cd
# 43                         6ª                     Cd
# 44                         7ª                     Cl
# 45                         8ª                     Cd
# 46                                                 1
# 47               $135.823.275                   26,0
# 48  Intense For Me $9.861.250            $89.590.900
# 49                      11,3%  Full Keid $15.000.000
#
#             tipo_carrera_alt                  distancia  \
# 0                                                 1400m
# 1                                                 1600m
# 2                                                 1700m
# 3                                                 1700m
# 4                                                 1600m
# 5                                                 1400m
# 6                                                 1400m
# 7                                                 1000m
# 8                                                 1000m
# 9                                                 1000m
# 10                                                1000m
# 11                                                1200m
# 12                                                1000m
# 13                                                1000m
# 14                                                1200m
# 15                        CH                      1600m
# 16                                                1000m
# 17                      ClCd                      1000m
# 18                                                1000m
# 19                                                1400m
# 20                                                1000m
# 21                                                1400m
# 22                                                1000m
# 23                                                1200m
# 24                                                1000m
# 25                                                1000m
# 26                                                1400m
# 27                                                1100m
# 28                                                1400m
# 29                                                1000m
# 30                                                1600m
# 31                                                1000m
# 32                                                1400m
# 33                                                1000m
# 34                                                1400m
# 35                                                1000m
# 36                                                1600m
# 37                                                1200m
# 38                                                1600m
# 39                                                1600m
# 40                                                1200m
# 41                                                1200m
# 42                                                1200m
# 43                                                1200m
# 44                                                1200m
# 45                                                1200m
# 46  Il Campione (Scat Daddy)                   119 / 49
# 47                         2  Fortify (Distorted Humor)
# 48                      23,5                          3
# 49               $71.503.580                       20,5
#
#                                     lugar_1  \
# 0        1° Lastchanceatglory (Goldencents)
# 1                       1° Sara Y (Bizarro)
# 2                    1° Nina Coral (Galvan)
# 3                   1° Snowzilla (Brethren)
# 4   1° Electric Beautiful (Handsome Franco)
# 5             1° Just a Factor (The Factor)
# 6       1° Eclipticolada (Social Inclusion)
# 7           1° Y A Quien No (Until Sundown)
# 8             1° Aragonero (The Lumber Guy)
# 9                   1° Merkel (Grand Daddy)
# 10                1° Pepe seis (Gemologist)
# 11          1° Toruk Makto (The Lumber Guy)
# 12                    1° Kat Fever (Katmai)
# 13     1° La Scaloneta (Patternrecognition)
# 14                1° Mi Tio Beltran (Flyer)
# 15                 1° Vitral (Court Vision)
# 16             1° Love Today (Sweet Sorrel)
# 17       1° Proactical Joy (Practical Joke)
# 18       1° Mas Que Linda (Awesome Patriot)
# 19                1° Nocciola (Exaggerator)
# 20          1° Merengada (Competitive Edge)
# 21                    1° Neuer (Imperia II)
# 22             1° Green Spirit (Gemologist)
# 23        1° Greco Eclipsado (Constitution)
# 24           1° La Martinoka (Gran Villano)
# 25             1° Sub Joke (Practical Joke)
# 26      1° Rio Escondido (Puerto Escondido)
# 27               1° Patagonia Rye (E Dubai)
# 28               1° Sun Ride (El Prado Rob)
# 29                   1° Zelai (Chuck Berry)
# 30           1° Profe Lu (Lunatico Emperor)
# 31              1° Lunar Bird (Il Campione)
# 32                         1° Blend (Forge)
# 33                1° Tac -Tac (Manipulator)
# 34           1° Surfing Boy (Hurricane Cat)
# 35       1° Country Ville (Nashville Texan)
# 36          1° Costa Cancion (Grand Reward)
# 37            1° Roma Kiin Ha (Señor Candy)
# 38                        1° Uhtred (Tokay)
# 39               1° Don Haidar (Poker Face)
# 40             1° Everglades (Que Fenomeno)
# 41                1° Único Lô (Wired Bryan)
# 42             1° It's Wysiwyg (Goldikovic)
# 43               1° Mazequeen (Wired Bryan)
# 44     1° Celestial Kitten (Camelot Kitten)
# 45                   1° Horus Hill (Koller)
# 46                                    4 / 5
# 47                                  98 / 21
# 48                  Full Mast (Mizzen Mast)
# 49                                        4
#
#                                      lugar_2  \
# 0                  2° Husky Driver (Outwork)
# 1            2° Flor de Maga (Harlan's Pure)
# 2                   2° Emprendedor (Ante Up)
# 3            2° La Resistencia (Lord Nelson)
# 4   2° Destiny's Charms (Believe in Royalty)
# 5                   2° My Love Puchu (Klimt)
# 6                         2° Inara (Mo Town)
# 7       2° Emiliana's Blue (Daddy Long Legs)
# 8                     2° Iron Swim (Admiral)
# 9        2° Wonder Woman (California Chrome)
# 10      2° Sahara Chrome (California Chrome)
# 11              2° Alazan Lucero (Flameaway)
# 12      2° Silver Prince (California Chrome)
# 13     2° Chica De Campeones (Annual Report)
# 14            2° Rapido En Llamas (Sky Mesa)
# 15              2° Latour Cent (Goldencents)
# 16            2° Tranquilo Ronaldo (Mo Town)
# 17              2° Golden Mist (Exaggerator)
